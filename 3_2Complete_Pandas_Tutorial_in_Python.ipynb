# %% [markdown]
# <a href="https://colab.research.google.com/github/farid22022/Machine_Learning_From_Zero_to_Hero/blob/main/3_2Complete_Pandas_Tutorial_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas Library
# Usefull for Data Processing & Analysis
#
# Pandas Data Frame
# Pandas DataFrame is two-dimensional tabular data structure with labeled axes (rows snd columns)

# %%
import pandas as pd
import numpy as np
pd.read_csv('./diabetes.csv')
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# Creating a Pandas DataFrame

# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing(as_frame=True)
type(housing)
print(type(housing))
# Out:
# <class 'sklearn.utils._bunch.Bunch'>

# %%
print(housing)
# Out:
# {'data':        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
#pandas data frame
housing_df = pd.DataFrame(housing, columns=housing.feature_names)

# %%
housing_df.head()
# Out:
# Empty DataFrame
# Columns: [MedInc, HouseAge, AveRooms, AveBedrms, Population, AveOccup, Latitude, Longitude]
# Index: []

# %%
from sklearn.datasets import fetch_california_housing

housing = fetch_california_housing(as_frame=True)

# This already contains all data + headers
housing_df = housing.frame

print(housing_df.head())
print(housing_df.shape)
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422
# (20640, 9)
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# ...

# %%
housing_df.shape
# Out:
# (20640, 9)

# %%
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing(as_frame=True)

housing_df = housing.frame
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %% [markdown]
# Impoeritng the data from a CSV fi;e to a pandas DataFrame

# %%
#csv file to pandas df
diabets_df = pd.read_csv('/content/diabetes.csv')

# %%
type(diabets_df)
type(housing_df)
print(type(diabets_df))
print(type(housing_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
diabets_df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# 1.   Loading the data from a excel file to a Pandas DataFrame
# 2.   pd.read_excel('file_name')

# %% [markdown]
# Exporting a Dataset into a csv file

# %%
housing_df.to_csv('housing.csv')

# %%
new_housing = pd.read_csv('./housing.csv')
new_housing.head()
# Out:
#    Unnamed: 0  MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0           0  8.3252      41.0  6.984127   1.023810       322.0  2.555556
# 1           1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842
# 2           2  7.2574      52.0  8.288136   1.073446       496.0  2.802260
# 3           3  5.6431      52.0  5.817352   1.073059       558.0  2.547945
# 4           4  3.8462      52.0  6.281853   1.081081       565.0  2.181467
#
#    Latitude  Longitude  MedHouseVal
# 0     37.88    -122.23        4.526
# 1     37.86    -122.22        3.585
# 2     37.85    -122.24        3.521
# 3     37.85    -122.25        3.413
# 4     37.85    -122.25        3.422
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# ...

# %% [markdown]
# Exporting the Pandas DataFrame to an excel File:
# 1. df.to_excel('filename')

# %%
# creating a DataFrame with random values
random_df = pd.DataFrame(np.random.rand(200,100))

# %%
random_df.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  0.481080  0.150678  0.178199  0.900494  0.864815  0.937292  0.917557
# 1  0.614261  0.479761  0.172341  0.907368  0.160702  0.204509  0.571173
# 2  0.352813  0.092083  0.294646  0.235575  0.745344  0.299872  0.571224
# 3  0.297020  0.899351  0.418086  0.219522  0.195964  0.399956  0.581212
# 4  0.005869  0.380594  0.046148  0.714812  0.502195  0.463038  0.447553
#
#          7         8         9   ...        90        91        92        93  \
# 0  0.562693  0.219452  0.511622  ...  0.009444  0.269883  0.505605  0.775433
# 1  0.021715  0.124631  0.798068  ...  0.731131  0.181064  0.283539  0.132324
# 2  0.992792  0.092519  0.491415  ...  0.165343  0.694273  0.768534  0.821059
# 3  0.196674  0.070407  0.072081  ...  0.434448  0.229733  0.292198  0.006784
# 4  0.007562  0.574178  0.831348  ...  0.462314  0.519669  0.006297  0.931850
#
#          94        95        96        97        98        99
# ...

# %%
random_df.shape
# Out:
# (200, 100)

# %% [markdown]
# Inspeating DataFrame

# %%
housing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %% [markdown]
# Number of missing value

# %%
housing_df.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %% [markdown]
# Counting the values based on the labels

# %%
housing_df.value_counts('Latitude')
# Out:
# Latitude
# 34.06    244
# 34.05    236
# 34.08    234
# 34.07    231
# 34.04    221
#         ...
# 41.23      1
# 41.28      1
# 41.30      1
# 41.88      1
# 41.92      1
# Name: count, Length: 862, dtype: int64

# %% [markdown]
# Group the value based on the mean

# %%
housing_df.groupby('Latitude').mean()
# Out:
#             MedInc   HouseAge  AveRooms  AveBedrms   Population  AveOccup  \
# Latitude
# 32.54     1.266700   7.000000  3.326241   1.053191  1187.000000  4.209220
# 32.55     2.343833   9.333333  4.242959   1.044896  3530.666667  3.932016
# 32.56     2.764300  15.500000  4.341508   1.043155  2238.700000  5.150666
# 32.57     3.368961  19.277778  5.074204   1.012189  1781.500000  3.895275
# 32.58     3.385735  22.730769  4.866881   1.026222  1367.192308  3.344389
# ...            ...        ...       ...        ...          ...       ...
# 41.84     3.031300  17.000000  5.870614   1.164474  1244.000000  2.728070
# 41.86     2.232067  24.000000  5.891849   1.209441  1532.333333  2.677139
# 41.88     3.130000  18.000000  5.829457   1.383721   660.000000  2.558140
# 41.92     2.133600  19.000000  5.893993   1.144876   841.000000  2.971731
# 41.95     2.049600  19.500000  5.701675   1.260179  1005.000000  2.499742
#
#            Longitude  MedHouseVal
# Latitude
# ...

# %% [markdown]
# Staistical Measures

# %% [markdown]
# Count or number or values

# %%
housing_df.count()
# Out:
# MedInc         20640
# HouseAge       20640
# AveRooms       20640
# AveBedrms      20640
# Population     20640
# AveOccup       20640
# Latitude       20640
# Longitude      20640
# MedHouseVal    20640
# dtype: int64

# %%
#mean value - column wise
housing_df.mean()
# Out:
# MedInc            3.870671
# HouseAge         28.639486
# AveRooms          5.429000
# AveBedrms         1.096675
# Population     1425.476744
# AveOccup          3.070655
# Latitude         35.631861
# Longitude      -119.569704
# MedHouseVal       2.068558
# dtype: float64

# %% [markdown]
# Standard deviation

# %%
#Standard deviation
housing_df.std()
# Out:
# MedInc            1.899822
# HouseAge         12.585558
# AveRooms          2.474173
# AveBedrms         0.473911
# Population     1132.462122
# AveOccup         10.386050
# Latitude          2.135952
# Longitude         2.003532
# MedHouseVal       1.153956
# dtype: float64

# %% [markdown]
# Minimum value

# %%
housing_df.min()
# Out:
# MedInc           0.499900
# HouseAge         1.000000
# AveRooms         0.846154
# AveBedrms        0.333333
# Population       3.000000
# AveOccup         0.692308
# Latitude        32.540000
# Longitude     -124.350000
# MedHouseVal      0.149990
# dtype: float64

# %% [markdown]
# maximum value of each column

# %%
housing_df.max()
# Out:
# MedInc            15.000100
# HouseAge          52.000000
# AveRooms         141.909091
# AveBedrms         34.066667
# Population     35682.000000
# AveOccup        1243.333333
# Latitude          41.950000
# Longitude       -114.310000
# MedHouseVal        5.000010
# dtype: float64

# %% [markdown]
# All the the statistical measures about the DataFrame

# %%
housing_df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %% [markdown]
# Manipulating a DataFrame

# %%
housing_df['price'] = housing.target

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %% [markdown]
# Removing first index=0

# %%
housing_df.drop(index=0,axis=0)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# 5      4.0368      52.0  4.761658   1.103627       413.0  2.139896     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  price
# ...

# %% [markdown]
# Drop a column

# %%
housing_df.drop(column = 'MedInc')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1882229543.py in <cell line: 0>()
# ----> 1 housing_df.drop(column = 'MedInc')
#
# TypeError: DataFrame.drop() got an unexpected keyword argument 'column'

# %%
housing_df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_129['MedInc'].plot(kind='hist', bins=20, title='MedInc')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
housing_df.drop(columns='MedInc', axis=1)
# Out:
#        HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0          41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1          21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2          52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3          52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4          52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...         ...       ...        ...         ...       ...       ...
# 20635      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  price
# 0        -122.23  4.526
# 1        -122.22  3.585
# 2        -122.24  3.521
# 3        -122.25  3.413
# ...

# %%
# locating a row using the index value
housing_df.iloc[2]
# Out:
# MedInc          7.257400
# HouseAge       52.000000
# AveRooms        8.288136
# AveBedrms       1.073446
# Population    496.000000
# AveOccup        2.802260
# Latitude       37.850000
# Longitude    -122.240000
# price           3.521000
# Name: 2, dtype: float64

# %%
# locating a particular column
print(housing_df.iloc[:,0]) # first column
print(housing_df.iloc[:,5])
print(housing_df.iloc[:,-1]) # last column
# Out:
# 0        8.3252
# 1        8.3014
# 2        7.2574
# 3        5.6431
# 4        3.8462
#           ...
# 20635    1.5603
# 20636    2.5568
# 20637    1.7000
# 20638    1.8672
# 20639    2.3886
# Name: MedInc, Length: 20640, dtype: float64
# 0        2.555556
# 1        2.109842
# 2        2.802260
# 3        2.547945
# 4        2.181467
#            ...
# 20635    2.560606
# 20636    3.122807
# 20637    2.325635
# 20638    2.123209
# 20639    2.616981
# Name: AveOccup, Length: 20640, dtype: float64
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: price, Length: 20640, dtype: float64

# %% [markdown]
# Correlation:
# 1. Posititve Correlation
# 2. Negative Correlation

# %%
housing_df.corr()
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...
