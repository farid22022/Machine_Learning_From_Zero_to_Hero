# %% [markdown]
# <a href="https://colab.research.google.com/github/farid22022/Machine_Learning_From_Zero_to_Hero/blob/main/4_2_Impoerting_Datasets_Through_Kaggle_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# API - Application Programming Interface

# %%
# !pip install kaggle

# %% [markdown]
# Upload Kaggel.json file

# %%
# configuring the path of Kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# IMporting the Earthquake Dataset

# %%
# API to fetch the dataset from Kaggle
# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# ...
#  99% 2.26G/2.27G [00:32<00:00, 34.4MB/s]
# 100% 2.27G/2.27G [00:32<00:00, 74.4MB/s]

# %%
import zipfile
import os

# Path where the zip file was saved
zip_path = "/content/LANL-Earthquake-Prediction.zip"
extract_dir = "/content/earthquake_data"

# Extract all
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# List extracted files
print(os.listdir(extract_dir))
# Out:
# ['train.csv', 'test', 'sample_submission.csv']
